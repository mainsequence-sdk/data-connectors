# %%
import pandas as pd

# %%
master_list=pd.read_csv("/home/jose/Downloads/demo_data/sp500_equity_security_master.csv")

# %%
master_list
# Out:
#        SecId Tickers                TickersStartToEndDate  \
# 0      18679  ACE;CB  20070103:20160114;20160115:29991231
# 1      32703     AOS                    20070103:29991231
# 2      32721     ABT                    20070103:29991231
# 3      32839    ADBE                    20070103:29991231
# 4      32840     TAP                    20070103:29991231
# ..       ...     ...                                  ...
# 502  8685065     TEL                    20240930:29991231
# 503  8726848      SW                    20240708:29991231
# 504  9075227    APTV                    20241220:29991231
# 505  9558357    PSKY                    20250807:29991231
# 506    73235   IR;TT  20070103:20200228;20200302:29991231
#
#                                                   Name  \
# 0                               ACE Ltd.;Chubb Limited
# 1                                     A.O. Smith Corp.
# 2                                  Abbott Laboratories
# ...

# %%
master_list.columns
# Out:
# Index(['SecId', 'Tickers', 'TickersStartToEndDate', 'Name',
#        'NameStartToEndDate', 'ISIN', 'ISINStartToEndDate', 'ListStatus',
#        'SecurityDescription', 'USIdentifier', 'USIdentifierStartToEndDate',
#        'PrimaryExchange', 'PrimaryExchangeStartToEndDate', 'SEDOL', 'Sic',
#        'Sector', 'Industry', 'FIGI'],
#       dtype='object')

# %%
daily_sample=pd.read_csv("/home/jose/Downloads/demo_data/us-equity-daily-ohlc-primary-secid-20220101-20220630/18679.csv")

# %%
daily_sample.columns
# Out:
# Index(['SecId', 'TradeDate', 'Ticker', 'Name', 'PrimaryExchange', 'ISIN',
#        'OpenPrice', 'OpenSize', 'OpenTime', 'HighPrice', 'HighTime',
#        'LowPrice', 'LowTime', 'ClosePrice', 'CloseSize', 'CloseTime',
#        'ListedMarketHoursVolume', 'ListedMarketHoursTrades',
#        'ListedTotalVolume', 'ListedTotalTrades', 'FinraMarketHoursVolume',
#        'FinraMarketHoursTrades', 'FinraTotalVolume', 'FinraTotalTrades',
#        'CumulativePriceFactor', 'CumulativeVolumeFactor', 'AdjustmentFactor',
#        'AdjustmentReason', 'MarketVWAP', 'DailyVWAP'],
#       dtype='object')
